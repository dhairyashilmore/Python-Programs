# %% [markdown]
# #WAP to calculate the cube of num

# %%
num1 = 3
print(num1**num1)
# Out:
# 27

# %% [markdown]
# #WAP to area of recangle

# %%
l = int(input("Enter a length : "))
h = int(input("Enter a height : "))
area = l * h
print(area)
# Out:
# 100

# %% [markdown]
# WAP to area of perimeter

# %%
l = int(input("Enter a length : "))
h = int(input("Enter a height : "))
perimeter = 2*(l + h)
print(perimeter)
# Out:
# 16

# %% [markdown]
# #WAP area of circle

# %%
re = int(input("Enter a redius : "))
area = 2*3.14*re
print(area)
# Out:
# 62.800000000000004

# %% [markdown]
# WAP Area of square

# %%
side1 = 10
side2 = 20

area = side1*side2
print(area)
# Out:
# 200

# %% [markdown]
# WAP to calculate the simple interest

# %%
amount = 173000
rate_of_interest = 10
Time = 3

SI = (amount * rate_of_interest * Time) / 100
print(SI)
# Out:
# 51900.0

# %% [markdown]
# WAP to calculate the simple interest

# %%
test1 = 53
test2 = 56
test3 = 67

per  = test1 + test2 + test3 / 100
print(per)
# Out:
# 109.67
